# %%
# COMPLEX DATATYPE ASSIGNMENT
# ==========================

# SOLVED EXAMPLE
# --------------
# Question: Create a complex number and find its conjugate
print("SOLVED EXAMPLE:")
print("Create a complex number and find its conjugate")
z = 3 + 4j
conjugate = z.conjugate()
magnitude = abs(z)
print(f"Complex number: {z}")
print(f"Conjugate: {conjugate}")
print(f"Magnitude: {magnitude}")
print("-" * 50)

# ASSIGNMENT QUESTIONS
# ===================

# %%
# Question 1: Create complex number 5 + 3j
print("Question 1: Create complex number 5 + 3j")

complex_number = 10+3j

print(f"Complex number : {complex_number}")
# Out:
# Question 1: Create complex number 5 + 3j
# Complex number : (10+3j)

# %%
# Question 2: Find the real part of complex number 7 - 2j
print("\nQuestion 2: Find the real part of complex number 7 - 2j")

complex_number= 7 - 2j

real_part = complex_number.real

print(f"Real part :{real_part} ")
# Out:
# Question 2: Find the real part of complex number 7 - 2j
# Real part :7.0

# %%
# Question 3: Find the imaginary part of complex number 4 + 6j
print("\nQuestion 3: Find the imaginary part of complex number 4 + 6j")

complex_number = 4 + 6j
imaginary_part = complex_number.imag

print(f"Imaginary Part: {imaginary_part}")
# Out:
# Question 3: Find the imaginary part of complex number 4 + 6j
# Imaginary Part: 6.0

# %%
# Question 4: Add two complex numbers: (3 + 2j) and (1 + 4j)
print("\nQuestion 4: Add two complex numbers: (3 + 2j) and (1 + 4j)")

complex_num_1=(3 + 2j)
complex_num_2 =(1+4j)

output=complex_num_1 + complex_num_2

print(f"Addtion of two complex number : {output}")
# Out:
# Question 4: Add two complex numbers: (3 + 2j) and (1 + 4j)
# Addtion of two complex number : (4+6j)

# %%
# Question 5: Multiply two complex numbers: (2 + 3j) and (1 + 2j)
print("\nQuestion 5: Multiply two complex numbers: (2 + 3j) and (1 + 2j)")

complex_num_1 = (2 + 3j)
complex_num_2 = (1 + 2j)

result = complex_num_1 * complex_num_2

print(f"Multiplication of two complex numbers : {result}")
# Out:
# Question 5: Multiply two complex numbers: (2 + 3j) and (1 + 2j)
# Multiplication of two complex numbers : (-4+7j)

# %%
# Question 6: Find the magnitude of complex number 6 + 8j
print("\nQuestion 6: Find the magnitude of complex number 6 + 8j")

complex_number = 6 + 8j

magnitude = abs(complex_number)

print(f"Magnitude of {complex_number} : {magnitude}")
# Out:
# Question 6: Find the magnitude of complex number 6 + 8j
# Magnitude of (6+8j) : 10.0

# %%
# Question 7: Find the conjugate of complex number 5 - 7j
print("\nQuestion 7: Find the conjugate of complex number 5 - 7j")

complex_number = 5 - 7j

conjugate = complex_number.conjugate()

print(f"Conjugate of {complex_number} : {conjugate}")
# Out:
# Question 7: Find the conjugate of complex number 5 - 7j
# Conjugate of (5-7j) : (5+7j)

# %%
# Question 8: Subtract complex numbers: (10 + 5j) - (3 + 2j)
print("\nQuestion 8: Subtract complex numbers: (10 + 5j) - (3 + 2j)")

num1 = (10 + 5j) 

num2 =  (3 + 2j)

result = num1 - num2

print(f"Subtraction of {num1}-{num2} = {result}")
# Out:
# Question 8: Subtract complex numbers: (10 + 5j) - (3 + 2j)
# Subtraction of (10+5j)-(3+2j) = (7+3j)

# %%
# Question 9: Divide complex numbers: (8 + 6j) / (2 + 1j)
print("\nQuestion 9: Divide complex numbers: (8 + 6j) / (2 + 1j)")

num_1 = (8 + 6j) 

num_2 = (2 + 1j)

result = num_1/num_2

print(f"Division of Two complex number is {result}")
# Out:
# Question 9: Divide complex numbers: (8 + 6j) / (2 + 1j)
# Division of Two complex number is (4.4+0.8j)

# %%
# Question 10: Find the phase angle of complex number 1 + 1j
print("\nQuestion 10: Find the phase angle of complex number 1 + 1j")

import math 

complex_number = 1 + 1j

phase_angle = math.pi / 4

print(f"the phase angle of complex number {complex_number} is : {phase_angle:.2f}")
# Out:
# Question 10: Find the phase angle of complex number 1 + 1j
# the phase angle of complex number (1+1j) is : 0.79
